# %%
#python program to get the third side of right-angled triangle from given two sides
import math
Base=float(input("Enter base:"))
Height=float(input("Enter Height:"))
C=math.sqrt(Base**2+Height**2)
print("Hypotenuse:",C)
# Out:
# Enter base:10
# Enter Height:5
# Hypotenuse: 11.180339887498949
